# %% [markdown]
# # 東京都23区ごとの放置自転車数を解析しよう

# %% [markdown]
# ### このノートブックでやること
#
# * ArcGIS Online へ ArcGIS for Develoers のアカウントを使ってログインする
# * Jupyter Notebook へ地図を表示させる
# * フィーチャ レイヤーの作成①：CSV の中身を pandas で確認しよう！
# * フィーチャ レイヤーの作成②：CSV からフィーチャサービスを公開しよう！※フィーチャ サービスは作成したらどんなもんか見てみよう
# * フィーチャ レイヤーの作成③：公開したフィーチャサービスを Jupyter Notebook の地図に追加しよう！
# * 解析：東京都 23 区ごとの放置自転車数を解析する
# * グラフ表示
# * Web マップの形で出力しよう

# %% [markdown]
# ### ArcGIS for Develoersのアカウントを使ってログインする

# %%
# ArcGIS for Developers ログイン情報
develoersUser = ''
develoersPass = ''

# %%
from arcgis.gis import GIS
gis = GIS("http://www.arcgis.com/",develoersUser,develoersPass)
user = gis.users.get(develoersUser)
user
# Out:
# <User username:ejpythondev>

# %%
# ArcGIS for Developers で使えるクレジット数（おまけ）
beforeCredit = gis.admin.credits.credits
beforeCredit
# Out:
# 48.775528

# %% [markdown]
# ### Jupyter Notebookへ地図を表示させる

# %%
geodevmap = gis.map("東京都", zoomlevel = 12)
geodevmap

# %% [markdown]
# ### フィーチャ レイヤーの作成①：CSVの中身をpandasで確認しよう！
# 手順
# * (データ準備)
# * データ読み込み
# * 中身の確認

# %% [markdown]
# ##### データ取得

# %% [markdown]
# 使用する CSV ファイルを入手します。
# githubからcloneまたはzipでノートブックをダウンロードすると次のフォルダに格納しています。
#
# C:<任意のフォルダ>\arcgis-samples-python-api-master\arcgis-samples-python-api-master>tree /f
# -  handson\meetup
#          │  Meetup Hands On!.ipynb
#          │
#          └─data
#              illegal_parking_2015.csv
#
# ダウンロード元
#
# [東京都内の放置自転車（2015）](https://hub.arcgis.com/datasets/ejopendataportal::%E6%9D%B1%E4%BA%AC%E9%83%BD%E5%86%85%E3%81%AE%E6%94%BE%E7%BD%AE%E8%87%AA%E8%BB%A2%E8%BB%8A%EF%BC%882015%EF%BC%89)
#
# ページ右側の「ダウンロード」ボタンから[スプレッドシート]を選択して任意の場所に保存します。
#
# ファイル名は次でお願いします
# * illegal_parking_2015.csv

# %% [markdown]
# ##### 中身の確認

# %%
# csvファイルの読み込み
illegal_parking_csv = 'data/illegal_parking_2015.csv'
illegal_parking_csv
# Out:
# 'data/illegal_parking_2015.csv'

# %%
import pandas as pd
from IPython.display import display
dataflame = pd.read_csv(illegal_parking_csv)
display(dataflame)
# Out:
#               X          Y  OBJECTID             駅名  放置台数_自転車  放置台数_原付  \
# 0    139.839999  35.747602         1          お花茶屋駅        74        7
# 1    139.778647  35.629825         2       お台場海浜公園駅       116        0
# 2    139.481864  35.517121         3         すずかけ台駅         0        0
# 3    139.484984  35.527165         4          つくし野駅         0        0
# 4    139.798637  35.712376         5   つくばエクスプレス浅草駅       301       22
# 5    139.574951  35.657928         6         つつじヶ丘駅        27        0
# 587  139.737173  35.716973       588           茗荷谷駅        58        0
# 588  139.778292  35.721226       589            鶯谷駅       206        8
#
#      放置台数_自二  実収容台数_自転車  実収容台数_原付  収容能力_自転車  収容能力_原付  F_TEST
# 0          0        892         8      2927       58    2035
# 1          0        217        10       217       20       0
# 2          0        253        53       253       80       0
# 3          0         39        99       275      155     236
# 4          8        282         0       760        0     478
# 5          0       3113        79      4370      135    1257
# 6          1          0         0         0        0       0
# 7          0        513         0      1920        0    1407
# 8          8       1212        13      1686       55     474
# 9          2       3902       106      5381      182    1479
# 10         0        274        83       638      317     364
# 11         8       3138        11      3461       43     323
# 12         2        160         1       274       18     114
# 13         2       7825        82     10867      192    3042
# 14         0        181         0       420       15     239
# 15         5        881         2      1451       11     570
# 16         0        811        17      1764       87     953
# 17         0       3370        39      4636       46    1266
# 18         1         76         0        76        0       0
# 19         0        654       123       791      180     137
# 20         0       1286        52      1372       53      86
# 21         0       2778        43      4175       50    1397
# 22         1        109         0       123        0      14
# 23         1         86        18       165       20      79
# 24         0        158         3       253        4      95
# 25         0        730         3       893        7     163
# 26         0       1131       128      1856      536     725
# 27         2        898         2      1537        7     639
# 28         2        266         0       300        0      34
# 29         0         10         5        25        5      15
# ..       ...        ...       ...       ...      ...     ...
# 559        0        793        19      1152       40     359
# 560        0        827        68       973       83     146
# 561        0        118         0       174        0      56
# 562        2          6         0        80        0      74
# 563        2        419         4       860       11     441
# 564        5       2997        31      3340       89     343
# 565        0        719         1       927       10     208
# 566        0        273         0       295        0      22
# 567        1        525         3       755       29     230
# 568        1        170        44       277       87     107
# 569        7       7109       190     11396      353    4287
# 570        2          0         0         0        0       0
# 571       12         84        18        84       18       0
# 572        1          0         0         0        0       0
# 573       23        611         0       814        0     203
# 574        1        209         0       353        7     144
# 575        0        390         2       803        5     413
# 576        4       2525        43      3179       98     654
# 577        1       1293        16      1451       41     158
# 578        0        721         1      1044       10     323
# 579        1        841        23       957       23     116
# 580        0         54        24       150       53      96
# 581        0        660         6       681       10      21
# 582        0       3439        51      5413      132    1974
# 583        0          0         0         0        0       0
# 584        1        148         0       344        0     196
# 585        0       1178        71      1320       89     142
# 586        0        742         0       990        0     248
# 587        0        337         0       460        0     123
# 588        8        646         0       670        0      24
#
# [589 rows x 12 columns]

# %% [markdown]
# ### フィーチャ レイヤーの作成②：CSVからフィーチャサービスを公開しよう！

# %%
# CSV ファイルを ArcGIS Online へアップロード
illegal_parking_bicycles = gis.content.add({},illegal_parking_csv)

# %%
# アップロードした CSV ファイルもとにフィーチャ レイヤーを作成・公開する
illegal_parking_bicycles_layer = illegal_parking_bicycles.publish()
illegal_parking_bicycles_layer
# ArcGIS Online へログインしてアイテムを確認してみましょう。
# Out:
# <Item title:"illegal_parking_2015" type:Feature Layer Collection owner:ejpythondev>

# %% [markdown]
# ### フィーチャ レイヤーの作成③：公開したフィーチャサービスを Jupyter Notebook の地図に追加しよう！

# %%
geodevmap.add_layer(illegal_parking_bicycles_layer)
# このあと地図をみてみましょう！↑

# %% [markdown]
# ### 解析：東京都 23 区ごとの放置自転車数を解析する
# 東京都のポリゴン（図形データ）を使って、区ごとに次のことを解析して求めます。
# * ポリゴン内のポイントの数
# * ポリゴン内のそれぞれのポイントが持つ属性情報で「放置自転車数」を合算する
#
# 手順
# * 東京都のポリゴンデータを呼び出す
# * ArcGIS Online のエリア集計の解析を実行する

# %% [markdown]
# ##### 東京都のポリゴンデータを呼び出す

# %%
# 目的データの検索
flayer_search_result = gis.content.search("title:境界線表示用 AND owner:Chikako_OD","Feature Layer", outside_org=True)
flayer_search_result

# cf :ArcGIS Opendata 
# http://hub.arcgis.com/datasets/ejopendataportal::%E5%B9%B3%E6%88%90-24-%E5%B9%B4%E7%B5%8C%E6%B8%88%E3%82%BB%E3%83%B3%E3%82%B5%E3%82%B9-%E6%B4%BB%E5%8B%95%E8%AA%BF%E6%9F%BB%EF%BC%88%E6%9D%B1%E4%BA%AC%E9%83%BD-23-%E5%8C%BA%E3%80%81%E5%A2%83%E7%95%8C%E7%B7%9A%E8%A1%A8%E7%A4%BA%E7%94%A8%EF%BC%89
# Out:
# [<Item title:"平成 24 年経済センサス 活動調査（東京都 23 区、境界線表示用）" type:Feature Layer Collection owner:Chikako_OD>]

# %%
# 東京都のポリゴンレイヤーを表示している地図に重ねる
geodevmap.add_layer(flayer_search_result[0])
# このあと地図をみてみましょう！↑

# %% [markdown]
# ##### ArcGIS Online のエリア集計の解析を実行する

# %%
from arcgis.features import summarize_data
summarize_layer = summarize_data.summarize_within(flayer_search_result[0],
                                illegal_parking_bicycles_layer,
                                sum_shape=True,
                                shape_units='SquareMiles',
                                summary_fields=["放置台数_自転車 SUM"],
                                output_name='東京都エリア集計_2015',
                                gis=gis)
summarize_layer
# Out:
# <Item title:"東京都エリア集計_2015" type:Feature Layer Collection owner:ejpythondev>

# %%
# 解析結果を地図へ表示する
geodevmap.add_layer(summarize_layer)
# このあと地図をみてみましょう！↑

# %% [markdown]
# ### グラフ表示
# エリア集計解析結果を見てみよう

# %%
import requests
import io
import pandas
from IPython.display import display
import json

# %%
layer = summarize_layer.layers[0]
layer.query().df
# Out:
#            AREA  AnalysisArea CITY CITY_1 CSS_NAME KEN KEN_NAME KIGO_I  \
# 0     48581.443      4.372601  101    101     千代田区  13      東京都
# 1   1869886.225      4.165976  102    102      中央区  13      東京都
# 2    159371.869      8.234020  103    103       港区  13      東京都
# 3     71488.615      7.051436  104    104      新宿区  13      東京都
# 4    110982.845      4.389739  105    105      文京区  13      東京都
# 5     66212.024      3.894807  106    106      台東区  13      東京都
# 6    194629.730      5.298058  107    107      墨田区  13      東京都
# 7    428855.447     16.976896  108    108      江東区  13      東京都
# 8    121110.112      9.059130  109    109      品川区  13      東京都
# 9     97978.226      5.713775  110    110      目黒区  13      東京都
# 10    44361.059     23.889949  111    111      大田区  13      東京都
# 14  35.70060  {'rings': [[[15542447.968, 4263710.4127], [155...
# 15  35.73521  {'rings': [[[15553281.76, 4265657.5184], [1555...
# 16  35.75006  {'rings': [[[15551520.3689, 4272563.2081], [15...
# 17  35.73474  {'rings': [[[15559065.9756, 4266771.3118], [15...
# 18  35.76123  {'rings': [[[15550799.4064, 4272999.138], [155...
# 19  35.73439  {'rings': [[[15543381.0802, 4269998.3098], [15...
# 20  35.75889  {'rings': [[[15559809.1058, 4274780.8912], [15...
# 21  35.74904  {'rings': [[[15570574.3555, 4272749.9305], [15...
# 22  35.63946  {'rings': [[[15572511.5115, 4266345.8903], [15...

# %% [markdown]
# #### 必要な要素だけで見てみよう

# %%
illegal_parking_bicycles_df = layer.query().df
# 3つの要素だけで表示
filtered_df = illegal_parking_bicycles_df[['CSS_NAME', 'SUM_放置台数_自転車','Point_Count']]
# 要素でソートして表示
sorted_df = filtered_df.sort_values(by='SUM_放置台数_自転車',ascending=False)
sorted_df
# Out:
#    CSS_NAME  SUM_放置台数_自転車  Point_Count
# 0      千代田区          3819           17
# 5       台東区          2359           13
# 11     世田谷区          2216           37
# 3       新宿区          2169           27
# 18      板橋区          2142           18
# 2        港区          1862           30
# 7       江東区          1526           27
# 16       北区          1509           13
# 10      大田区          1418           35
# 1       中央区          1377           20
# 6       墨田区          1273           13
# 14      杉並区          1174           18
# 8       品川区          1153           25
# 15      豊島区          1130           16
# 13      中野区           875           13
# 4       文京区           789           13
# 19      練馬区           643           18
# 21      葛飾区           606           11
# 12      渋谷区           519           16
# 17      荒川区           415           10
# 9       目黒区           326            9
# 22     江戸川区           246           11
# 20      足立区           185           23

# %%
import matplotlib.pyplot as pd
from matplotlib.font_manager import FontProperties
# matplotlibはデフォルトで日本語フォントをもっていないそうなので、豆腐（文字化け）の場合はフォントを指定します。
fp = FontProperties(fname=r'data/ipaexg.ttf', size=11)
# fp = FontProperties(fname=r'D:\\ProgramFiles\\Fonts\\ipaexg.ttf', size=11)
# グラフの設定
graphdata = sorted_df.plot(x='CSS_NAME', y='SUM_放置台数_自転車', kind='bar', figsize=(10,10))
graphdata.set_xticklabels(sorted_df['CSS_NAME'], fontproperties=fp)
graphdata.set_xlabel('CSS_NAME', fontproperties=fp)
pd.show()
pd.close()
# Out:
# D:\ProgramFiles\python\anaconda3\lib\site-packages\matplotlib\font_manager.py:1316: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Web マップ作成

# %%
import arcgis
from arcgis.gis import GIS
from arcgis.mapping import WebMap

web_map_properties = {'title':'MeetupHandsOn228',
                     'snippet':'GeoDev Meetup ハンズオンで作成した Web マップ',
                     'tags':'geodev_jp'}

# %%
web_map_item = geodevmap.save(item_properties=web_map_properties)
web_map_item
# Out:
# <Item title:"MeetupHandsOn228" type:Web Map owner:ejpythondev>

# %%
# 指定のURLを別ブラウザで表示する
import webbrowser
url = "http://www.arcgis.com/home/webmap/viewer.html?webmap=" + web_map_item.itemid
webbrowser.open(url)
# Out:
# True
